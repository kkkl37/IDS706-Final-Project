# %%
import pandas as pd

# %% [markdown]
# ## Credit Dataset

# %%
credit = pd.read_csv("/Users/emma/Downloads/tmdb_5000_credits.csv")

# %%
credit = credit.rename({"movie_id":"id"}, axis = 1)

# %%
credit = credit[["id","title", "cast", "crew"]]

# %%
credit["crew"] = credit["crew"].apply(eval)
credit["cast"] = credit["cast"].apply(eval)

# %%
director = []
for i in range(len(credit["crew"])):
    dir = []
    for j in range(len(credit["crew"][i])):
        if credit["crew"][i][j]["job"] == "Director":
            dir.append(credit["crew"][i][j]["name"])
    director.append(dir)
credit["director"]=director

# %%
credit.sample(20)
# Out:
#           id                             title  \
# 3940     670                            Oldboy
# 2783  158011                          The Call
# 2423   26602                      Summer Catch
# 639    12133                     Step Brothers
# 1742  254473                    Brick Mansions
# 1521   24662                  Cats Don't Dance
# 4488  376004                        Adulterers
# 4053    9731  Friday the 13th: A New Beginning
# 4420   84178                        Black Rock
# 1664  102362                     Dead Man Down
# 1983   40688                  Meet the Deedles
# 416     9339                             Click
# 3263   37735                            Easy A
# 66     14160                                Up
# 1592    4105                        Black Rain
# 1919  133698                Fly Me to the Moon
# 88    177572                        Big Hero 6
# 3247  225565               That Awkward Moment
# 180     2503              The Bourne Ultimatum
# 701    10992                       Cats & Dogs
#
#                                                    cast  \
# 3940  [{'cast_id': 13, 'character': 'Oh Dae-su', 'cr...
# 2783  [{'cast_id': 4, 'character': 'Jordan Turner', ...
# 2423  [{'cast_id': 1, 'character': 'Ryan Dunne', 'cr...
# 639   [{'cast_id': 10, 'character': 'Brennan Huff', ...
# 1742  [{'cast_id': 1, 'character': 'Damien Collier',...
# 1521  [{'cast_id': 2, 'character': 'Danny', 'credit_...
# 4488  [{'cast_id': 1, 'character': 'Samuel Deuprey',...
# 4053  [{'cast_id': 16, 'character': 'Pam Roberts', '...
# 4420  [{'cast_id': 1, 'character': 'Sarah', 'credit_...
# 1664  [{'cast_id': 1, 'character': 'Victor', 'credit...
# 1983  [{'cast_id': 1, 'character': 'Phil Deedle', 'c...
# 416   [{'cast_id': 1, 'character': 'Michael Newman',...
# 3263  [{'cast_id': 1, 'character': 'Olive Penderghas...
# 66    [{'cast_id': 4, 'character': 'Carl Fredricksen...
# 1592  [{'cast_id': 1, 'character': 'Nick', 'credit_i...
# 1919  [{'cast_id': 2, 'character': 'Isabelle', 'cred...
# 88    [{'cast_id': 23, 'character': 'Baymax (voice)'...
# 3247  [{'cast_id': 1, 'character': 'Jason', 'credit_...
# 180   [{'cast_id': 8, 'character': 'Jason Bourne', '...
# 701   [{'cast_id': 1, 'character': 'Professor Brody'...
#
#                                                    crew  \
# 3940  [{'credit_id': '52fe4267c3a36847f801bd35', 'de...
# 2783  [{'credit_id': '52fe4bd99251416c910e78d1', 'de...
# 2423  [{'credit_id': '52fe450ec3a368484e045d67', 'de...
# 639   [{'credit_id': '57695a139251415ca50002ae', 'de...
# 1742  [{'credit_id': '52fe4ebd9251416c9113c123', 'de...
# 1521  [{'credit_id': '56a4c4c5925141524c001bcf', 'de...
# 4488  [{'credit_id': '5694d0739251414b67001ae9', 'de...
# 4053  [{'credit_id': '52fe4523c3a36847f80bea15', 'de...
# 4420  [{'credit_id': '52fe48de9251416c9109ae59', 'de...
# 1664  [{'credit_id': '52fe4a07c3a36847f81b458b', 'de...
# 1983  [{'credit_id': '565ca60e9251415d1f00043b', 'de...
# 416   [{'credit_id': '52fe44e9c3a36847f80b1757', 'de...
# 3263  [{'credit_id': '578beedec3a3682bb200b2ac', 'de...
# 66    [{'credit_id': '5683b5f8c3a3684be90168e1', 'de...
# 1592  [{'credit_id': '575ca5e89251412b68000667', 'de...
# 1919  [{'credit_id': '52fe4bb9c3a368484e1969cb', 'de...
# 88    [{'credit_id': '537534e7c3a3681efb0002b3', 'de...
# 3247  [{'credit_id': '5640e4cdc3a36814d9000325', 'de...
# 180   [{'credit_id': '52fe435bc3a36847f804e2c1', 'de...
# 701   [{'credit_id': '52fe43de9251416c75021451', 'de...
#
#                         director
# 3940            [Park Chan-wook]
# 2783             [Brad Anderson]
# 2423               [Mike Tollin]
# 639                 [Adam McKay]
# 1742         [Camille Delamarre]
# 1521               [Mark Dindal]
# 4488              [H.M. Coakley]
# 4053           [Danny Steinmann]
# 4420             [Katie Aselton]
# 1664         [Niels Arden Oplev]
# 1983               [Steve Boyum]
# 416               [Frank Coraci]
# 3263                [Will Gluck]
# 66                 [Pete Docter]
# 1592              [Ridley Scott]
# 1919           [Pascal Chaumeil]
# 88    [Chris Williams, Don Hall]
# 3247              [Tom Gormican]
# 180            [Paul Greengrass]
# 701          [Lawrence Guterman]

# %%
actor = []
for i in range(len(credit["cast"])):
    act = []
    for j in range(len(credit["cast"][i])):
            act.append(credit["cast"][i][j]["name"])
    actor.append(act)
credit["actor"]= actor

# %%
credit.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew             director  \
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...      [James Cameron]
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...     [Gore Verbinski]
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...         [Sam Mendes]
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...  [Christopher Nolan]
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...     [Andrew Stanton]
#
#                                                actor
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %% [markdown]
# ## Movie Datset

# %%
movie = pd.read_csv("/Users/emma/Downloads/tmdb_5000_movies.csv")

# %%
movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movie = movie[["id", "genres", "keywords", "popularity", "release_date", "vote_average", "vote_count", "runtime"]]

# %%
movie["genres"] = movie["genres"].apply(eval)
movie["keywords"] = movie["keywords"].apply(eval)

# %%
movie["genres"] [0]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
genre = []
for i in range(len(movie["genres"])):
    gen = []
    for j in range(len(movie["genres"][i])):
            gen.append(movie["genres"][i][j]["name"])
    genre.append(gen)
movie["genres_list"] = genre

# %%
keys = []
for i in range(len(movie["keywords"])):
    key = []
    for j in range(len(movie["keywords"][i])):
            key.append(movie["keywords"][i][j]["name"])
    keys.append(key)
movie["key"] = keys

# %%
movie['year'] = pd.DatetimeIndex(movie['release_date']).year

# %%
"True" in movie.year.isnull()
# Out:
# False

# %%
movie.head(3)
# Out:
#        id                                             genres  \
# 0   19995  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1     285  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  206647  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             keywords  popularity release_date  \
# 0  [{'id': 1463, 'name': 'culture clash'}, {'id':...  150.437577   2009-12-10
# 1  [{'id': 270, 'name': 'ocean'}, {'id': 726, 'na...  139.082615   2007-05-19
# 2  [{'id': 470, 'name': 'spy'}, {'id': 818, 'name...  107.376788   2015-10-26
#
#    vote_average  vote_count  runtime  \
# 0           7.2       11800    162.0
# 1           6.9        4500    169.0
# 2           6.3        4466    148.0
#
#                                      genres_list  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
#
#                                                  key    year
# 0  [culture clash, future, space war, space colon...  2009.0
# 1  [ocean, drug abuse, exotic island, east india ...  2007.0
# 2  [spy, based on novel, secret agent, sequel, mi...  2015.0

# %%
credit.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
#
#                                                 crew          director  \
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...   [James Cameron]
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...  [Gore Verbinski]
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...      [Sam Mendes]
#
#                                                actor
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...

# %%
df = credit.merge(movie, how = "left")

# %%
df = df.drop(["cast", "crew", "genres", "keywords", "release_date"], axis = 1)

# %%
df.to_csv("clean_df.csv")
